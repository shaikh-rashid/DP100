# %% [markdown]
# # Creating a Pipeline
#
# In the previous labs, you used the Azure Machine Learning SDK to explore the entire model training process from accessing data through to running training experiments and registering machine learning models. Up until now, you have performed the various steps required to create a machine learning solution interactively. In this lab, you'll explore automation of these steps using *pipelines*.
#
# ## Connect to Your Workspace
#
# The first thing you need to do is to connect to your workspace using the Azure ML SDK.
#
# > **Note**: If the authenticated session with your Azure subscription has expired since you completed the previous exercise, you'll be prompted to reauthenticate.

# %%
import azureml.core
from azureml.core import Workspace

# Load the workspace from the saved config file
ws = Workspace.from_config()
print('Ready to use Azure ML {} to work with {}'.format(azureml.core.VERSION, ws.name))
# Out:
# Ready to use Azure ML 1.5.0 to work with azure-ml-demo

# %% [markdown]
# ## Prepare Data for an Experiment
#
# In this lab, you'll use a dataset containing details of diabetes patients. Run the cell below to create this dataset (if you created it in the previous lab, the code will find the existing version)

# %%
from azureml.core import Dataset

default_ds = ws.get_default_datastore()

if 'diabetes dataset' not in ws.datasets:
    default_ds.upload_files(files=['./data/diabetes.csv', './data/diabetes2.csv'], # Upload the diabetes csv files in /data
                        target_path='diabetes-data/', # Put it in a folder path in the datastore
                        overwrite=True, # Replace existing files of the same name
                        show_progress=True)

    #Create a tabular dataset from the path on the datastore (this may take a short while)
    tab_data_set = Dataset.Tabular.from_delimited_files(path=(default_ds, 'diabetes-data/*.csv'))

    # Register the tabular dataset
    try:
        tab_data_set = tab_data_set.register(workspace=ws, 
                                name='diabetes dataset',
                                description='diabetes data',
                                tags = {'format':'CSV'},
                                create_new_version=True)
        print('Dataset registered.')
    except Exception as ex:
        print(ex)
else:
    print('Dataset already registered.')
# Out:
# Dataset already registered.

# %% [markdown]
# ## Create Scripts for Pipeline Steps
#
# Pipelines consist of one or more *steps*, which can be Python scripts, or specialized steps like an Auto ML training estimator or a data transfer step that copies data from one location to another. Each step can run in its own compute context.
#
# In this exercise, you'll build a simple pipeline that contains an estimator step (to train a model) and a Python script step (to register the trained model).

# %%
import os
# Create a folder for the pipeline step files
experiment_folder = 'diabetes_pipeline'
os.makedirs(experiment_folder, exist_ok=True)

print(experiment_folder)
# Out:
# diabetes_pipeline

# %% [markdown]
# Now you can create the script for the first step, which will train a model. The script includes a parameter named **output_folder**, which references the folder where the trained model should be saved.

# %%
# %%writefile $experiment_folder/train_diabetes.py
# Import libraries
from azureml.core import Run
import argparse
import pandas as pd
import numpy as np
import joblib
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
import matplotlib.pyplot as plt

# Get parameters
parser = argparse.ArgumentParser()
parser.add_argument('--output_folder', type=str, dest='output_folder', default="diabetes_model", help='output folder')
args = parser.parse_args()
output_folder = args.output_folder

# Get the experiment run context
run = Run.get_context()

# load the diabetes data (passed as an input dataset)
print("Loading Data...")
diabetes = run.input_datasets['diabetes_train'].to_pandas_dataframe()

# Separate features and labels
X, y = diabetes[['Pregnancies','PlasmaGlucose','DiastolicBloodPressure','TricepsThickness','SerumInsulin','BMI','DiabetesPedigree','Age']].values, diabetes['Diabetic'].values

# Split data into training set and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=0)

# Train adecision tree model
print('Training a decision tree model')
model = DecisionTreeClassifier().fit(X_train, y_train)

# calculate accuracy
y_hat = model.predict(X_test)
acc = np.average(y_hat == y_test)
print('Accuracy:', acc)
run.log('Accuracy', np.float(acc))

# calculate AUC
y_scores = model.predict_proba(X_test)
auc = roc_auc_score(y_test,y_scores[:,1])
print('AUC: ' + str(auc))
run.log('AUC', np.float(auc))

# plot ROC curve
fpr, tpr, thresholds = roc_curve(y_test, y_scores[:,1])
fig = plt.figure(figsize=(6, 4))
# Plot the diagonal 50% line
plt.plot([0, 1], [0, 1], 'k--')
# Plot the FPR and TPR achieved by our model
plt.plot(fpr, tpr)
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
run.log_image(name = "ROC", plot = fig)
plt.show()

# Save the trained model
os.makedirs(output_folder, exist_ok=True)
output_path = output_folder + "/model.pkl"
joblib.dump(value=model, filename=output_path)

run.complete()
# Out:
# Writing diabetes_pipeline/train_diabetes.py

# %% [markdown]
# The script for the second step of the pipeline will load the model from where it was saved, and then register it in the workspace. It includes a single **model_folder** parameter that contains the path where the model was saved.

# %%
# %%writefile $experiment_folder/register_diabetes.py
# Import libraries
import argparse
import joblib
from azureml.core import Workspace, Model, Run

# Get parameters
parser = argparse.ArgumentParser()
parser.add_argument('--model_folder', type=str, dest='model_folder', default="diabetes_model", help='model location')
args = parser.parse_args()
model_folder = args.model_folder

# Get the experiment run context
run = Run.get_context()

# load the model
print("Loading model from " + model_folder)
model_file = model_folder + "/model.pkl"
model = joblib.load(model_file)

Model.register(workspace=run.experiment.workspace,
               model_path = model_file,
               model_name = 'diabetes_model',
               tags={'Training context':'Pipeline'})

run.complete()
# Out:
# Writing diabetes_pipeline/register_diabetes.py

# %% [markdown]
# ## Prepare a Compute Environment for the Pipeline Steps
#
# In this exercise, you'll use the same compute for both steps, but it's important to realize that each step is run independently; so you could specify different compute contexts for each step if appropriate.
#
# First, get the compute target.

# %%
from azureml.core.compute import ComputeTarget, AmlCompute
from azureml.core.compute_target import ComputeTargetException

cluster_name = "aml-cluster"

# Verify that cluster exists
try:
    pipeline_cluster = ComputeTarget(workspace=ws, name=cluster_name)
    print('Found existing cluster, use it.')
except ComputeTargetException:
    # If not, create it
    compute_config = AmlCompute.provisioning_configuration(vm_size='STANDARD_DS2_V2', 
                                                           max_nodes=2)
    pipeline_cluster = ComputeTarget.create(ws, cluster_name, compute_config)

pipeline_cluster.wait_for_completion(show_output=True)
# Out:
# Found existing cluster, use it.
# Succeeded
# AmlCompute wait for completion finished
#
# Minimum number of nodes requested have been provisioned

# %% [markdown]
# The compute will require a Python environment with the necessary package dependencies installed, so you'll need to create a run configuration.

# %%
from azureml.core import Environment
from azureml.core.conda_dependencies import CondaDependencies
from azureml.core.runconfig import RunConfiguration

# Create a Python environment for the experiment
diabetes_env = Environment("diabetes-experiment-env")
diabetes_env.python.user_managed_dependencies = False # Let Azure ML manage dependencies
diabetes_env.docker.enabled = True # Use a docker container

# Create a set of package dependencies
diabetes_packages = CondaDependencies.create(conda_packages=['scikit-learn','ipykernel','matplotlib', 'pandas'],
                                             pip_packages=['azureml-sdk','pyarrow'])

# Add the dependencies to the environment
diabetes_env.python.conda_dependencies = diabetes_packages

# Register the environment (just in case previous lab wasn't completed)
diabetes_env.register(workspace=ws)
registered_env = Environment.get(ws, 'diabetes-experiment-env')

# Create a new runconfig object for the pipeline
pipeline_run_config = RunConfiguration()

# Use the compute you created above. 
pipeline_run_config.target = pipeline_cluster

# Assign the environment to the run configuration
pipeline_run_config.environment = registered_env

print ("Run configuration created.")
# Out:
# Run configuration created.

# %% [markdown]
# ## Create and Run a Pipeline
#
# Now you're ready to create and run a pipeline.
#
# First you need to define the steps for the pipeline, and any data references that need to passed between them. In this case, the first step must write the model to a folder that can be read from by the second step. Since the steps will be run on remote compute (and in fact, could each be run on different compute), the folder path must be passed as a data reference to a location in a datastore within the workspace. The **PipelineData** object is a special kind of data reference that is used for interim storage locations that can be passed between pipeline steps, so you'll create one and use at as the output for the first step and the input for the second step. Note that you also need to pass it as a script argument so our code can access the datastore location referenced by the data reference.

# %%
from azureml.pipeline.core import PipelineData
from azureml.pipeline.steps import PythonScriptStep, EstimatorStep
from azureml.train.estimator import Estimator

# Get the training dataset
diabetes_ds = ws.datasets.get("diabetes dataset")

# Create a PipelineData (temporary Data Reference) for the model folder
model_folder = PipelineData("model_folder", datastore=ws.get_default_datastore())

estimator = Estimator(source_directory=experiment_folder,
                        compute_target = pipeline_cluster,
                        environment_definition=pipeline_run_config.environment,
                        entry_script='train_diabetes.py')

train_step = EstimatorStep(name = "Train Model",
                           estimator=estimator, 
                           estimator_entry_script_arguments=['--output_folder', model_folder],
                           inputs=[diabetes_ds.as_named_input('diabetes_train')],
                           outputs=[model_folder],
                           compute_target = pipeline_cluster,
                           allow_reuse = True)

# Step 2, run the model registration script
register_step = PythonScriptStep(name = "Register Model",
                                source_directory = experiment_folder,
                                script_name = "register_diabetes.py",
                                arguments = ['--model_folder', model_folder],
                                inputs=[model_folder],
                                compute_target = pipeline_cluster,
                                runconfig = pipeline_run_config,
                                allow_reuse = True)

print("Pipeline steps defined")
# Out:
# Pipeline steps defined

# %% [markdown]
# OK, you're ready build the pipeline from the steps you've defined and run it as an experiment.

# %%
from azureml.core import Experiment
from azureml.pipeline.core import Pipeline
from azureml.widgets import RunDetails

# Construct the pipeline
pipeline_steps = [train_step, register_step]
pipeline = Pipeline(workspace = ws, steps=pipeline_steps)
print("Pipeline is built.")

# Create an experiment and run the pipeline
experiment = Experiment(workspace = ws, name = 'diabetes-training-pipeline')
pipeline_run = experiment.submit(pipeline, regenerate_outputs=True)
print("Pipeline submitted for execution.")

RunDetails(pipeline_run).show()
pipeline_run.wait_for_completion()
# Out:
# Pipeline is built.
# Created step Train Model [f2acd9b2][c2b9c321-c097-4c62-ac82-70f50bc9f038], (This step will run and generate new outputs)
# Created step Register Model [d08718c3][c385c4a7-4ea6-442e-b15e-aec4a3b9b0e7], (This step will run and generate new outputs)
# Submitted PipelineRun 65df44a8-7d53-418a-aba7-7dd5c754150f
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/diabetes-training-pipeline/runs/65df44a8-7d53-418a-aba7-7dd5c754150f?wsid=/subscriptions/2a43b2d1-03c5-46d9-aa44-98475cf19902/resourcegroups/azure-ml-demo/workspaces/azure-ml-demo
# Pipeline submitted for execution.
# _PipelineWidget(widget_settings={'childWidgetDisplay': 'popup', 'send_telemetry': False, 'log_level': 'INFO', …
# PipelineRunId: 65df44a8-7d53-418a-aba7-7dd5c754150f
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/diabetes-training-pipeline/runs/65df44a8-7d53-418a-aba7-7dd5c754150f?wsid=/subscriptions/2a43b2d1-03c5-46d9-aa44-98475cf19902/resourcegroups/azure-ml-demo/workspaces/azure-ml-demo
# PipelineRun Status: NotStarted
# PipelineRun Status: Running
#
#
# StepRunId: 0f877866-e0fe-452f-b14b-610cdf8609cf
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/diabetes-training-pipeline/runs/0f877866-e0fe-452f-b14b-610cdf8609cf?wsid=/subscriptions/2a43b2d1-03c5-46d9-aa44-98475cf19902/resourcegroups/azure-ml-demo/workspaces/azure-ml-demo
# StepRun( Train Model ) Status: NotStarted
# StepRun( Train Model ) Status: Running
#
# Streaming azureml-logs/20_image_build_log.txt
# =============================================
# 2020/05/18 13:19:23 Downloading source code...
# 2020/05/18 13:19:24 Finished downloading source code
# 2020/05/18 13:19:25 Creating Docker network: acb_default_network, driver: 'bridge'
# 2020/05/18 13:19:25 Successfully set up Docker network: acb_default_network
# 2020/05/18 13:19:25 Setting up Docker configuration...
# 2020/05/18 13:19:26 Successfully set up Docker configuration
# 2020/05/18 13:19:26 Logging in to registry: azuremldemo9d15d93e.azurecr.io
# 2020/05/18 13:19:27 Successfully logged into azuremldemo9d15d93e.azurecr.io
# 2020/05/18 13:19:27 Executing step ID: acb_step_0. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2020/05/18 13:19:27 Scanning for dependencies...
# 2020/05/18 13:19:28 Successfully scanned dependencies
# 2020/05/18 13:19:28 Launching container with name: acb_step_0
# Sending build context to Docker daemon  60.93kB
#
# Step 1/15 : FROM mcr.microsoft.com/azureml/base:intelmpi2018.3-ubuntu16.04@sha256:a1b514f3ba884b9a7695cbba5638933ddaf222e8ce3e8c81e8cdf861679abb05
# sha256:a1b514f3ba884b9a7695cbba5638933ddaf222e8ce3e8c81e8cdf861679abb05: Pulling from azureml/base
# Digest: sha256:a1b514f3ba884b9a7695cbba5638933ddaf222e8ce3e8c81e8cdf861679abb05
# Status: Downloaded newer image for mcr.microsoft.com/azureml/base:intelmpi2018.3-ubuntu16.04@sha256:a1b514f3ba884b9a7695cbba5638933ddaf222e8ce3e8c81e8cdf861679abb05
#  ---> 93a72e6bd1ce
# Step 2/15 : USER root
#  ---> Running in ed5353428062
# Removing intermediate container ed5353428062
#  ---> b457bea28eb3
# Step 3/15 : RUN mkdir -p $HOME/.cache
#  ---> Running in 71864d00487c
# Removing intermediate container 71864d00487c
#  ---> fb46abc01ec8
# Step 4/15 : WORKDIR /
#  ---> Running in 0968507eccde
# Removing intermediate container 0968507eccde
#  ---> b40365c52a66
# Step 5/15 : COPY azureml-environment-setup/99brokenproxy /etc/apt/apt.conf.d/
#  ---> 3244ed73f668
# Step 6/15 : RUN if dpkg --compare-versions `conda --version | grep -oE '[^ ]+$'` lt 4.4.11; then conda install conda==4.4.11; fi
#  ---> Running in 1b69f9fad50f
# Removing intermediate container 1b69f9fad50f
#  ---> 3d65e613d612
# Step 7/15 : COPY azureml-environment-setup/mutated_conda_dependencies.yml azureml-environment-setup/mutated_conda_dependencies.yml
#  ---> fe4839d08184
# Step 8/15 : RUN ldconfig /usr/local/cuda/lib64/stubs && conda env create -p /azureml-envs/azureml_5d419b151e9c1ce888d07b7a6d7737fd -f azureml-environment-setup/mutated_conda_dependencies.yml && rm -rf "$HOME/.cache/pip" && conda clean -aqy && CONDA_ROOT_DIR=$(conda info --root) && rm -rf "$CONDA_ROOT_DIR/pkgs" && find "$CONDA_ROOT_DIR" -type d -name __pycache__ -exec rm -rf {} + && ldconfig
#  ---> Running in b643dab21a4c
# Solving environment: ...working...
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.5.11
#   latest version: 4.8.3
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# wheel-0.34.2         | 49 KB     |            |   0%
# wheel-0.34.2         | 49 KB     | ########## | 100%
#
# pcre-8.43            | 260 KB    |            |   0%
# pcre-8.43            | 260 KB    | ########## | 100%
#
# blas-1.0             | 6 KB      |            |   0%
# blas-1.0             | 6 KB      | ########## | 100%
#
# pyzmq-18.1.1         | 525 KB    |            |   0%
# pyzmq-18.1.1         | 525 KB    | ########5  |  85%
# pyzmq-18.1.1         | 525 KB    | ########## | 100%
#
# pandas-1.0.3         | 11.1 MB   |            |   0%
# pandas-1.0.3         | 11.1 MB   | ####6      |  46%
# pandas-1.0.3         | 11.1 MB   | #######5   |  75%
# pandas-1.0.3         | 11.1 MB   | #########3 |  94%
# pandas-1.0.3         | 11.1 MB   | ########## | 100%
#
# mkl_fft-1.0.15       | 173 KB    |            |   0%
# mkl_fft-1.0.15       | 173 KB    | ########## | 100%
#
# jedi-0.17.0          | 809 KB    |            |   0%
# jedi-0.17.0          | 809 KB    | ########2  |  83%
# jedi-0.17.0          | 809 KB    | ########## | 100%
#
# dbus-1.13.12         | 611 KB    |            |   0%
# dbus-1.13.12         | 611 KB    | ########9  |  89%
# dbus-1.13.12         | 611 KB    | ########## | 100%
#
# scipy-1.4.1          | 18.9 MB   |            |   0%
# scipy-1.4.1          | 18.9 MB   | ###8       |  39%
# scipy-1.4.1          | 18.9 MB   | #######5   |  75%
# scipy-1.4.1          | 18.9 MB   | #########1 |  92%
# scipy-1.4.1          | 18.9 MB   | ########## | 100%
#
# mkl-service-2.3.0    | 208 KB    |            |   0%
# mkl-service-2.3.0    | 208 KB    | ########## | 100%
#
# libedit-3.1          | 171 KB    |            |   0%
# libedit-3.1          | 171 KB    | ########## | 100%
#
# pytz-2020.1          | 239 KB    |            |   0%
# pytz-2020.1          | 239 KB    | #########3 |  93%
# pytz-2020.1          | 239 KB    | ########## | 100%
#
# readline-7.0         | 387 KB    |            |   0%
# readline-7.0         | 387 KB    | #########8 |  99%
# readline-7.0         | 387 KB    | ########## | 100%
#
# prompt-toolkit-3.0.4 | 240 KB    |            |   0%
# prompt-toolkit-3.0.4 | 240 KB    | #########4 |  94%
# prompt-toolkit-3.0.4 | 240 KB    | ########## | 100%
#
# pexpect-4.8.0        | 84 KB     |            |   0%
# pexpect-4.8.0        | 84 KB     | ########## | 100%
#
# traitlets-4.3.3      | 137 KB    |            |   0%
# traitlets-4.3.3      | 137 KB    | ########## | 100%
#
# scikit-learn-0.22.1  | 7.1 MB    |            |   0%
# scikit-learn-0.22.1  | 7.1 MB    | #######5   |  75%
# scikit-learn-0.22.1  | 7.1 MB    | #########7 |  98%
# scikit-learn-0.22.1  | 7.1 MB    | ########## | 100%
#
# jupyter_core-4.6.3   | 75 KB     |            |   0%
# jupyter_core-4.6.3   | 75 KB     | ########## | 100%
#
# libstdcxx-ng-9.1.0   | 4.0 MB    |            |   0%
# libstdcxx-ng-9.1.0   | 4.0 MB    | #######6   |  77%
# libstdcxx-ng-9.1.0   | 4.0 MB    | #########6 |  97%
# libstdcxx-ng-9.1.0   | 4.0 MB    | ########## | 100%
#
# numpy-1.18.1         | 5 KB      |            |   0%
# numpy-1.18.1         | 5 KB      | ########## | 100%
#
# mkl-2019.4           | 204.1 MB  |            |   0%
# mkl-2019.4           | 204.1 MB  | 3          |   3%
# mkl-2019.4           | 204.1 MB  | 7          |   8%
# mkl-2019.4           | 204.1 MB  | #2         |  12%
# mkl-2019.4           | 204.1 MB  | #6         |  17%
# mkl-2019.4           | 204.1 MB  | ##         |  21%
# mkl-2019.4           | 204.1 MB  | ##5        |  25%
# mkl-2019.4           | 204.1 MB  | ##9        |  30%
# mkl-2019.4           | 204.1 MB  | ###4       |  34%
# mkl-2019.4           | 204.1 MB  | ###8       |  39%
# mkl-2019.4           | 204.1 MB  | ####3      |  43%
# mkl-2019.4           | 204.1 MB  | ####7      |  48%
# mkl-2019.4           | 204.1 MB  | #####2     |  52%
# mkl-2019.4           | 204.1 MB  | #####6     |  57%
# mkl-2019.4           | 204.1 MB  | ######1    |  62%
# mkl-2019.4           | 204.1 MB  | ######6    |  66%
# mkl-2019.4           | 204.1 MB  | #######    |  70%
# mkl-2019.4           | 204.1 MB  | #######5   |  75%
# mkl-2019.4           | 204.1 MB  | #######9   |  79%
# mkl-2019.4           | 204.1 MB  | ########2  |  83%
# mkl-2019.4           | 204.1 MB  | ########4  |  85%
#
# mkl-2019.4           | 204.1 MB  | ########6  |  86%
# mkl-2019.4           | 204.1 MB  | ########7  |  88%
# mkl-2019.4           | 204.1 MB  | ########8  |  88%
# mkl-2019.4           | 204.1 MB  | ########8  |  89%
# mkl-2019.4           | 204.1 MB  | ########9  |  89%
# mkl-2019.4           | 204.1 MB  | ########9  |  90%
# mkl-2019.4           | 204.1 MB  | ########9  |  90%
# mkl-2019.4           | 204.1 MB  | #########  |  90%
# mkl-2019.4           | 204.1 MB  | #########  |  90%
# mkl-2019.4           | 204.1 MB  | #########  |  90%
# mkl-2019.4           | 204.1 MB  | #########  |  91%
# mkl-2019.4           | 204.1 MB  | #########  |  91%
# mkl-2019.4           | 204.1 MB  | #########  |  91%
# mkl-2019.4           | 204.1 MB  | #########  |  91%
# mkl-2019.4           | 204.1 MB  | #########  |  91%
# mkl-2019.4           | 204.1 MB  | #########1 |  91%
# mkl-2019.4           | 204.1 MB  | #########1 |  91%
# mkl-2019.4           | 204.1 MB  | #########1 |  91%
# mkl-2019.4           | 204.1 MB  | #########1 |  91%
# mkl-2019.4           | 204.1 MB  | #########1 |  91%
# mkl-2019.4           | 204.1 MB  | #########1 |  91%
# mkl-2019.4           | 204.1 MB  | #########1 |  91%
# mkl-2019.4           | 204.1 MB  | #########1 |  92%
# mkl-2019.4           | 204.1 MB  | #########1 |  92%
# mkl-2019.4           | 204.1 MB  | #########1 |  92%
# mkl-2019.4           | 204.1 MB  | #########1 |  92%
# mkl-2019.4           | 204.1 MB  | #########1 |  92%
# mkl-2019.4           | 204.1 MB  | #########1 |  92%
# mkl-2019.4           | 204.1 MB  | #########1 |  92%
# mkl-2019.4           | 204.1 MB  | #########2 |  92%
# mkl-2019.4           | 204.1 MB  | #########2 |  92%
# mkl-2019.4           | 204.1 MB  | #########2 |  92%
# mkl-2019.4           | 204.1 MB  | #########2 |  92%
# mkl-2019.4           | 204.1 MB  | #########2 |  92%
#
# mkl-2019.4           | 204.1 MB  | #########2 |  92%
# mkl-2019.4           | 204.1 MB  | #########2 |  93%
# mkl-2019.4           | 204.1 MB  | #########2 |  93%
# mkl-2019.4           | 204.1 MB  | #########2 |  93%
# mkl-2019.4           | 204.1 MB  | #########2 |  93%
# mkl-2019.4           | 204.1 MB  | #########2 |  93%
# mkl-2019.4           | 204.1 MB  | #########2 |  93%
# mkl-2019.4           | 204.1 MB  | #########2 |  93%
# mkl-2019.4           | 204.1 MB  | #########3 |  93%
# mkl-2019.4           | 204.1 MB  | #########3 |  93%
# mkl-2019.4           | 204.1 MB  | #########3 |  93%
# mkl-2019.4           | 204.1 MB  | #########3 |  93%
# mkl-2019.4           | 204.1 MB  | #########3 |  93%
# mkl-2019.4           | 204.1 MB  | #########3 |  93%
# mkl-2019.4           | 204.1 MB  | #########3 |  93%
# mkl-2019.4           | 204.1 MB  | #########3 |  94%
# mkl-2019.4           | 204.1 MB  | #########3 |  94%
# mkl-2019.4           | 204.1 MB  | #########3 |  94%
# mkl-2019.4           | 204.1 MB  | #########3 |  94%
# mkl-2019.4           | 204.1 MB  | #########3 |  94%
# mkl-2019.4           | 204.1 MB  | #########3 |  94%
# mkl-2019.4           | 204.1 MB  | #########3 |  94%
# mkl-2019.4           | 204.1 MB  | #########4 |  94%
# mkl-2019.4           | 204.1 MB  | #########4 |  94%
# mkl-2019.4           | 204.1 MB  | #########4 |  94%
# mkl-2019.4           | 204.1 MB  | #########4 |  94%
# mkl-2019.4           | 204.1 MB  | #########4 |  94%
# mkl-2019.4           | 204.1 MB  | #########4 |  94%
# mkl-2019.4           | 204.1 MB  | #########4 |  94%
# mkl-2019.4           | 204.1 MB  | #########4 |  95%
# mkl-2019.4           | 204.1 MB  | #########4 |  95%
# mkl-2019.4           | 204.1 MB  | #########4 |  95%
# mkl-2019.4           | 204.1 MB  | #########4 |  95%
# mkl-2019.4           | 204.1 MB  | #########4 |  95%
# mkl-2019.4           | 204.1 MB  | #########4 |  95%
# mkl-2019.4           | 204.1 MB  | #########4 |  95%
# mkl-2019.4           | 204.1 MB  | #########5 |  95%
# mkl-2019.4           | 204.1 MB  | #########5 |  95%
# mkl-2019.4           | 204.1 MB  | #########5 |  95%
# mkl-2019.4           | 204.1 MB  | #########5 |  95%
# mkl-2019.4           | 204.1 MB  | #########5 |  95%
# mkl-2019.4           | 204.1 MB  | #########5 |  95%
# mkl-2019.4           | 204.1 MB  | #########5 |  96%
# mkl-2019.4           | 204.1 MB  | #########5 |  96%
# mkl-2019.4           | 204.1 MB  | #########5 |  96%
# mkl-2019.4           | 204.1 MB  | #########5 |  96%
# mkl-2019.4           | 204.1 MB  | #########5 |  96%
# mkl-2019.4           | 204.1 MB  | #########5 |  96%
# mkl-2019.4           | 204.1 MB  | #########5 |  96%
# mkl-2019.4           | 204.1 MB  | #########5 |  96%
# mkl-2019.4           | 204.1 MB  | #########6 |  96%
# mkl-2019.4           | 204.1 MB  | #########6 |  96%
# mkl-2019.4           | 204.1 MB  | #########6 |  96%
# mkl-2019.4           | 204.1 MB  | #########6 |  96%
# mkl-2019.4           | 204.1 MB  | #########6 |  96%
# mkl-2019.4           | 204.1 MB  | #########6 |  96%
# mkl-2019.4           | 204.1 MB  | #########6 |  97%
# mkl-2019.4           | 204.1 MB  | #########6 |  97%
# mkl-2019.4           | 204.1 MB  | #########6 |  97%
# mkl-2019.4           | 204.1 MB  | #########6 |  97%
# mkl-2019.4           | 204.1 MB  | #########6 |  97%
# mkl-2019.4           | 204.1 MB  | #########6 |  97%
# mkl-2019.4           | 204.1 MB  | #########6 |  97%
# mkl-2019.4           | 204.1 MB  | #########7 |  97%
# mkl-2019.4           | 204.1 MB  | #########7 |  97%
# mkl-2019.4           | 204.1 MB  | #########7 |  97%
# mkl-2019.4           | 204.1 MB  | #########7 |  97%
# mkl-2019.4           | 204.1 MB  | #########7 |  97%
# mkl-2019.4           | 204.1 MB  | #########7 |  97%
# mkl-2019.4           | 204.1 MB  | #########7 |  97%
# mkl-2019.4           | 204.1 MB  | #########7 |  97%
# mkl-2019.4           | 204.1 MB  | #########7 |  98%
# mkl-2019.4           | 204.1 MB  | #########7 |  98%
# mkl-2019.4           | 204.1 MB  | #########7 |  98%
# mkl-2019.4           | 204.1 MB  | #########7 |  98%
# mkl-2019.4           | 204.1 MB  | #########7 |  98%
# mkl-2019.4           | 204.1 MB  | #########7 |  98%
# mkl-2019.4           | 204.1 MB  | #########7 |  98%
# mkl-2019.4           | 204.1 MB  | #########8 |  98%
# mkl-2019.4           | 204.1 MB  | #########8 |  98%
# mkl-2019.4           | 204.1 MB  | #########8 |  98%
# mkl-2019.4           | 204.1 MB  | #########8 |  98%
# mkl-2019.4           | 204.1 MB  | #########8 |  98%
# mkl-2019.4           | 204.1 MB  | #########8 |  98%
# mkl-2019.4           | 204.1 MB  | #########8 |  98%
# mkl-2019.4           | 204.1 MB  | #########8 |  99%
# mkl-2019.4           | 204.1 MB  | #########8 |  99%
# mkl-2019.4           | 204.1 MB  | #########8 |  99%
#
# mkl-2019.4           | 204.1 MB  | #########8 |  99%
# mkl-2019.4           | 204.1 MB  | #########8 |  99%
# mkl-2019.4           | 204.1 MB  | #########8 |  99%
# mkl-2019.4           | 204.1 MB  | #########8 |  99%
# mkl-2019.4           | 204.1 MB  | #########9 |  99%
# mkl-2019.4           | 204.1 MB  | #########9 |  99%
# mkl-2019.4           | 204.1 MB  | #########9 |  99%
# mkl-2019.4           | 204.1 MB  | #########9 |  99%
# mkl-2019.4           | 204.1 MB  | #########9 |  99%
# mkl-2019.4           | 204.1 MB  | #########9 |  99%
# mkl-2019.4           | 204.1 MB  | #########9 | 100%
# mkl-2019.4           | 204.1 MB  | #########9 | 100%
# mkl-2019.4           | 204.1 MB  | #########9 | 100%
# mkl-2019.4           | 204.1 MB  | #########9 | 100%
# mkl-2019.4           | 204.1 MB  | #########9 | 100%
# mkl-2019.4           | 204.1 MB  | #########9 | 100%
# mkl-2019.4           | 204.1 MB  | #########9 | 100%
# mkl-2019.4           | 204.1 MB  | ########## | 100%
#
# setuptools-46.2.0    | 674 KB    |            |   0%
# setuptools-46.2.0    | 674 KB    | ########4  |  84%
# setuptools-46.2.0    | 674 KB    | ########## | 100%
#
# glib-2.56.2          | 5.0 MB    |            |   0%
# glib-2.56.2          | 5.0 MB    | #######5   |  76%
# glib-2.56.2          | 5.0 MB    | ########9  |  90%
# glib-2.56.2          | 5.0 MB    | ########## | 100%
#
# pyparsing-2.4.7      | 64 KB     |            |   0%
# pyparsing-2.4.7      | 64 KB     | ########## | 100%
#
# gstreamer-1.14.0     | 3.8 MB    |            |   0%
# gstreamer-1.14.0     | 3.8 MB    | #######5   |  75%
# gstreamer-1.14.0     | 3.8 MB    | #########7 |  98%
# gstreamer-1.14.0     | 3.8 MB    | ########## | 100%
#
# icu-58.2             | 22.7 MB   |            |   0%
# icu-58.2             | 22.7 MB   | ##3        |  24%
# icu-58.2             | 22.7 MB   | #####9     |  59%
# icu-58.2             | 22.7 MB   | #######5   |  75%
# icu-58.2             | 22.7 MB   | #########  |  91%
# icu-58.2             | 22.7 MB   | ########## | 100%
#
# sqlite-3.23.1        | 1.5 MB    |            |   0%
# sqlite-3.23.1        | 1.5 MB    | ########1  |  82%
# sqlite-3.23.1        | 1.5 MB    | ########## | 100%
#
# qt-5.9.6             | 86.7 MB   |            |   0%
# qt-5.9.6             | 86.7 MB   | 4          |   4%
# qt-5.9.6             | 86.7 MB   | #2         |  12%
# qt-5.9.6             | 86.7 MB   | ##         |  21%
# qt-5.9.6             | 86.7 MB   | ###1       |  31%
# qt-5.9.6             | 86.7 MB   | ####2      |  43%
# qt-5.9.6             | 86.7 MB   | #####3     |  54%
# qt-5.9.6             | 86.7 MB   | ######4    |  65%
# qt-5.9.6             | 86.7 MB   | #######5   |  75%
# qt-5.9.6             | 86.7 MB   | ########4  |  84%
#
# qt-5.9.6             | 86.7 MB   | #########1 |  91%
# qt-5.9.6             | 86.7 MB   | #########5 |  96%
# qt-5.9.6             | 86.7 MB   | #########9 |  99%
# qt-5.9.6             | 86.7 MB   | ########## | 100%
#
# pickleshare-0.7.5    | 13 KB     |            |   0%
# pickleshare-0.7.5    | 13 KB     | ########## | 100%
#
# numpy-base-1.18.1    | 5.2 MB    |            |   0%
# numpy-base-1.18.1    | 5.2 MB    | #######6   |  76%
# numpy-base-1.18.1    | 5.2 MB    | #########1 |  92%
# numpy-base-1.18.1    | 5.2 MB    | ########## | 100%
#
# tk-8.6.8             | 3.1 MB    |            |   0%
# tk-8.6.8             | 3.1 MB    | #######6   |  77%
# tk-8.6.8             | 3.1 MB    | ########8  |  88%
# tk-8.6.8             | 3.1 MB    | #########7 |  98%
# tk-8.6.8             | 3.1 MB    | ########## | 100%
#
# pip-20.0.2           | 1.9 MB    |            |   0%
# pip-20.0.2           | 1.9 MB    | #######8   |  78%
# pip-20.0.2           | 1.9 MB    | #########5 |  95%
# pip-20.0.2           | 1.9 MB    | ########## | 100%
#
# parso-0.7.0          | 71 KB     |            |   0%
# parso-0.7.0          | 71 KB     | ########## | 100%
#
# ipython_genutils-0.2 | 39 KB     |            |   0%
# ipython_genutils-0.2 | 39 KB     | ########## | 100%
#
# decorator-4.4.2      | 14 KB     |            |   0%
# decorator-4.4.2      | 14 KB     | ########## | 100%
#
# libgfortran-ng-7.3.0 | 1.3 MB    |            |   0%
# libgfortran-ng-7.3.0 | 1.3 MB    | ########2  |  82%
# libgfortran-ng-7.3.0 | 1.3 MB    | ########## | 100%
#
# mkl_random-1.1.0     | 369 KB    |            |   0%
# mkl_random-1.1.0     | 369 KB    | ########## | 100%
#
# intel-openmp-2020.1  | 940 KB    |            |   0%
# intel-openmp-2020.1  | 940 KB    | ########1  |  82%
# intel-openmp-2020.1  | 940 KB    | ########## | 100%
#
# zeromq-4.3.1         | 666 KB    |            |   0%
# zeromq-4.3.1         | 666 KB    | ########7  |  87%
# zeromq-4.3.1         | 666 KB    | ########## | 100%
#
# pyqt-5.9.2           | 5.6 MB    |            |   0%
# pyqt-5.9.2           | 5.6 MB    | #######5   |  75%
# pyqt-5.9.2           | 5.6 MB    | ########7  |  87%
# pyqt-5.9.2           | 5.6 MB    | #########6 |  96%
# pyqt-5.9.2           | 5.6 MB    | ########## | 100%
#
# libpng-1.6.37        | 364 KB    |            |   0%
# libpng-1.6.37        | 364 KB    | ########## | 100%
#
# fontconfig-2.13.0    | 291 KB    |            |   0%
# fontconfig-2.13.0    | 291 KB    | ########## | 100%
#
# libuuid-1.0.3        | 16 KB     |            |   0%
# libuuid-1.0.3        | 16 KB     | ########## | 100%
#
# ipykernel-5.1.4      | 168 KB    |            |   0%
# ipykernel-5.1.4      | 168 KB    | ########## | 100%
#
# cycler-0.10.0        | 13 KB     |            |   0%
# cycler-0.10.0        | 13 KB     | ########## | 100%
#
# gst-plugins-base-1.1 | 6.3 MB    |            |   0%
# gst-plugins-base-1.1 | 6.3 MB    | #######5   |  75%
# gst-plugins-base-1.1 | 6.3 MB    | #########  |  90%
# gst-plugins-base-1.1 | 6.3 MB    | ########## | 100%
#
# libffi-3.2.1         | 43 KB     |            |   0%
# libffi-3.2.1         | 43 KB     | ########## | 100%
#
# zlib-1.2.11          | 120 KB    |            |   0%
# zlib-1.2.11          | 120 KB    | ########## | 100%
#
# matplotlib-base-3.1. | 6.6 MB    |            |   0%
# matplotlib-base-3.1. | 6.6 MB    | #######5   |  76%
# matplotlib-base-3.1. | 6.6 MB    | #########8 |  99%
# matplotlib-base-3.1. | 6.6 MB    | ########## | 100%
#
# ptyprocess-0.6.0     | 23 KB     |            |   0%
# ptyprocess-0.6.0     | 23 KB     | ########## | 100%
#
# python-dateutil-2.8. | 224 KB    |            |   0%
# python-dateutil-2.8. | 224 KB    | ########## | 100%
#
# ca-certificates-2020 | 132 KB    |            |   0%
# ca-certificates-2020 | 132 KB    | ########## | 100%
#
# libxcb-1.13          | 502 KB    |            |   0%
# libxcb-1.13          | 502 KB    | ########3  |  83%
# libxcb-1.13          | 502 KB    | ########## | 100%
#
# wcwidth-0.1.9        | 24 KB     |            |   0%
# wcwidth-0.1.9        | 24 KB     | ########## | 100%
#
# backcall-0.1.0       | 19 KB     |            |   0%
# backcall-0.1.0       | 19 KB     | ########## | 100%
#
# expat-2.2.6          | 187 KB    |            |   0%
# expat-2.2.6          | 187 KB    | ########## | 100%
#
# matplotlib-3.1.3     | 21 KB     |            |   0%
# matplotlib-3.1.3     | 21 KB     | ########## | 100%
#
# python-3.6.2         | 27.0 MB   |            |   0%
# python-3.6.2         | 27.0 MB   | #9         |  19%
# python-3.6.2         | 27.0 MB   | ####9      |  49%
# python-3.6.2         | 27.0 MB   | #######5   |  75%
# python-3.6.2         | 27.0 MB   | ########8  |  88%
# python-3.6.2         | 27.0 MB   | #########7 |  98%
# python-3.6.2         | 27.0 MB   | ########## | 100%
#
# certifi-2020.4.5.1   | 159 KB    |            |   0%
# certifi-2020.4.5.1   | 159 KB    | ########## | 100%
#
# ncurses-6.0          | 907 KB    |            |   0%
# ncurses-6.0          | 907 KB    | #######9   |  79%
# ncurses-6.0          | 907 KB    | #########3 |  93%
# ncurses-6.0          | 907 KB    | ########## | 100%
#
# jpeg-9b              | 247 KB    |            |   0%
# jpeg-9b              | 247 KB    | ########## | 100%
#
# pygments-2.6.1       | 687 KB    |            |   0%
# pygments-2.6.1       | 687 KB    | ########2  |  83%
# pygments-2.6.1       | 687 KB    | ########## | 100%
#
# ipython-7.13.0       | 1.1 MB    |            |   0%
# ipython-7.13.0       | 1.1 MB    | #######9   |  79%
# ipython-7.13.0       | 1.1 MB    | #########6 |  97%
# ipython-7.13.0       | 1.1 MB    | ########## | 100%
#
# six-1.14.0           | 27 KB     |            |   0%
# six-1.14.0           | 27 KB     | ########## | 100%
#
# kiwisolver-1.2.0     | 91 KB     |            |   0%
# kiwisolver-1.2.0     | 91 KB     | ########## | 100%
#
# joblib-0.14.1        | 202 KB    |            |   0%
# joblib-0.14.1        | 202 KB    | ########## | 100%
#
# entrypoints-0.3      | 12 KB     |            |   0%
# entrypoints-0.3      | 12 KB     | ########## | 100%
#
# tornado-6.0.4        | 650 KB    |            |   0%
# tornado-6.0.4        | 650 KB    | ########4  |  85%
# tornado-6.0.4        | 650 KB    | ########## | 100%
#
# libsodium-1.0.16     | 302 KB    |            |   0%
# libsodium-1.0.16     | 302 KB    | ########## | 100%
#
# freetype-2.9.1       | 822 KB    |            |   0%
# freetype-2.9.1       | 822 KB    | ########1  |  81%
# freetype-2.9.1       | 822 KB    | ########## | 100%
#
# prompt_toolkit-3.0.4 | 11 KB     |            |   0%
# prompt_toolkit-3.0.4 | 11 KB     | ########## | 100%
#
# libxml2-2.9.9        | 2.0 MB    |            |   0%
# libxml2-2.9.9        | 2.0 MB    | #######6   |  76%
# libxml2-2.9.9        | 2.0 MB    | #########9 |  99%
# libxml2-2.9.9        | 2.0 MB    | ########## | 100%
#
# sip-4.19.13          | 293 KB    |            |   0%
# sip-4.19.13          | 293 KB    | ########## | 100%
#
# openssl-1.0.2u       | 3.1 MB    |            |   0%
# openssl-1.0.2u       | 3.1 MB    | #######6   |  76%
# openssl-1.0.2u       | 3.1 MB    | #########5 |  96%
# openssl-1.0.2u       | 3.1 MB    | ########## | 100%
#
# libgcc-ng-9.1.0      | 8.1 MB    |            |   0%
# libgcc-ng-9.1.0      | 8.1 MB    | ######2    |  62%
# libgcc-ng-9.1.0      | 8.1 MB    | ########   |  81%
# libgcc-ng-9.1.0      | 8.1 MB    | #########5 |  96%
# libgcc-ng-9.1.0      | 8.1 MB    | ########## | 100%
#
# xz-5.2.5             | 438 KB    |            |   0%
# xz-5.2.5             | 438 KB    | #########2 |  93%
# xz-5.2.5             | 438 KB    | ########## | 100%
#
# jupyter_client-6.1.3 | 81 KB     |            |   0%
# jupyter_client-6.1.3 | 81 KB     | ########## | 100%
# Downloading and Extracting Packages
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working...
# done
# Collecting azureml-sdk
#   Downloading azureml_sdk-1.5.0-py3-none-any.whl (4.6 kB)
# Collecting pyarrow
#   Downloading pyarrow-0.17.0-cp36-cp36m-manylinux2014_x86_64.whl (63.8 MB)
# Collecting azureml-pipeline~=1.5.0
#   Downloading azureml_pipeline-1.5.0-py3-none-any.whl (3.7 kB)
# Collecting azureml-train-automl-client~=1.5.0
#   Downloading azureml_train_automl_client-1.5.0.post1-py3-none-any.whl (85 kB)
# Collecting azureml-train~=1.5.0
#   Downloading azureml_train-1.5.0-py3-none-any.whl (3.2 kB)
# Collecting azureml-dataprep[fuse]<1.6.0a,>=1.4.10a
#   Downloading azureml_dataprep-1.5.0-py3-none-any.whl (26.7 MB)
# Collecting azureml-core~=1.5.0
#   Downloading azureml_core-1.5.0.post4-py3-none-any.whl (1.3 MB)
# Requirement already satisfied: numpy>=1.14 in /azureml-envs/azureml_5d419b151e9c1ce888d07b7a6d7737fd/lib/python3.6/site-packages (from pyarrow->-r /azureml-environment-setup/condaenv.ru3wm5lg.requirements.txt (line 2)) (1.18.1)
# Collecting azureml-pipeline-steps~=1.5.0
#   Downloading azureml_pipeline_steps-1.5.0-py3-none-any.whl (51 kB)
# Collecting azureml-pipeline-core~=1.5.0
#   Downloading azureml_pipeline_core-1.5.0-py3-none-any.whl (277 kB)
# Collecting azureml-automl-core~=1.5.0
#   Downloading azureml_automl_core-1.5.0.post2-py3-none-any.whl (117 kB)
# Requirement already satisfied: pytz in /azureml-envs/azureml_5d419b151e9c1ce888d07b7a6d7737fd/lib/python3.6/site-packages (from azureml-train-automl-client~=1.5.0->azureml-sdk->-r /azureml-environment-setup/condaenv.ru3wm5lg.requirements.txt (line 1)) (2020.1)
# Collecting azureml-telemetry~=1.5.0
#   Downloading azureml_telemetry-1.5.0-py3-none-any.whl (29 kB)
# Collecting azureml-train-core~=1.5.0
#   Downloading azureml_train_core-1.5.0-py3-none-any.whl (8.6 MB)
# Collecting azureml-dataprep-native<15.0.0,>=14.1.0
#   Downloading azureml_dataprep_native-14.1.0-cp36-cp36m-manylinux1_x86_64.whl (1.3 MB)
# Collecting azure-identity<1.3.0,>=1.2.0
#   Downloading azure_identity-1.2.0-py2.py3-none-any.whl (58 kB)
# Collecting cloudpickle>=1.1.0
#   Downloading cloudpickle-1.4.1-py3-none-any.whl (26 kB)
# Collecting dotnetcore2>=2.1.14
#   Downloading dotnetcore2-2.1.14-py3-none-manylinux1_x86_64.whl (29.3 MB)
# Collecting fusepy>=3.0.1; extra == "fuse"
#   Downloading fusepy-3.0.1.tar.gz (11 kB)
# Collecting SecretStorage
#   Downloading SecretStorage-3.1.2-py3-none-any.whl (14 kB)
# Collecting azure-mgmt-keyvault>=0.40.0
#   Downloading azure_mgmt_keyvault-2.2.0-py2.py3-none-any.whl (89 kB)
# Collecting ndg-httpsclient
#   Downloading ndg_httpsclient-0.5.1-py3-none-any.whl (34 kB)
# Collecting contextlib2
#   Downloading contextlib2-0.6.0.post1-py2.py3-none-any.whl (9.8 kB)
# Collecting docker
#   Downloading docker-4.2.0-py2.py3-none-any.whl (143 kB)
# Collecting azure-mgmt-containerregistry>=2.0.0
#   Downloading azure_mgmt_containerregistry-2.8.0-py2.py3-none-any.whl (718 kB)
# Collecting jsonpickle
#   Downloading jsonpickle-1.4.1-py2.py3-none-any.whl (36 kB)
# Collecting ruamel.yaml>0.16.7
#   Downloading ruamel.yaml-0.16.10-py2.py3-none-any.whl (111 kB)
# Collecting azure-mgmt-resource>=1.2.1
#   Downloading azure_mgmt_resource-9.0.0-py2.py3-none-any.whl (807 kB)
# Collecting PyJWT
#   Downloading PyJWT-1.7.1-py2.py3-none-any.whl (18 kB)
# Collecting backports.tempfile
#   Downloading backports.tempfile-1.0-py2.py3-none-any.whl (4.4 kB)
# Collecting requests>=2.19.1
#   Downloading requests-2.23.0-py2.py3-none-any.whl (58 kB)
# Collecting msrestazure>=0.4.33
#   Downloading msrestazure-0.6.3-py2.py3-none-any.whl (40 kB)
# Collecting pyopenssl
#   Downloading pyOpenSSL-19.1.0-py2.py3-none-any.whl (53 kB)
# Collecting azure-graphrbac>=0.40.0
#   Downloading azure_graphrbac-0.61.1-py2.py3-none-any.whl (141 kB)
# Collecting azure-common>=1.1.12
#   Downloading azure_common-1.1.25-py2.py3-none-any.whl (12 kB)
# Requirement already satisfied: python-dateutil>=2.7.3 in /azureml-envs/azureml_5d419b151e9c1ce888d07b7a6d7737fd/lib/python3.6/site-packages (from azureml-core~=1.5.0->azureml-sdk->-r /azureml-environment-setup/condaenv.ru3wm5lg.requirements.txt (line 1)) (2.8.1)
# Collecting msrest>=0.5.1
#   Downloading msrest-0.6.13-py2.py3-none-any.whl (83 kB)
# Collecting jmespath
#   Downloading jmespath-0.10.0-py2.py3-none-any.whl (24 kB)
# Collecting azure-mgmt-authorization>=0.40.0
#   Downloading azure_mgmt_authorization-0.60.0-py2.py3-none-any.whl (82 kB)
# Collecting azure-mgmt-storage>=1.5.0
#   Downloading azure_mgmt_storage-10.0.0-py2.py3-none-any.whl (532 kB)
# Collecting azure-mgmt-network~=10.0
#   Downloading azure_mgmt_network-10.2.0-py2.py3-none-any.whl (8.6 MB)
# Collecting adal>=1.2.0
#   Downloading adal-1.2.3-py2.py3-none-any.whl (53 kB)
# Collecting urllib3>=1.23
#   Downloading urllib3-1.25.9-py2.py3-none-any.whl (126 kB)
# Collecting cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*
#   Downloading cryptography-2.9.2-cp35-abi3-manylinux2010_x86_64.whl (2.7 MB)
# Collecting pathspec
#   Downloading pathspec-0.8.0-py2.py3-none-any.whl (28 kB)
# Collecting applicationinsights
#   Downloading applicationinsights-0.11.9-py2.py3-none-any.whl (58 kB)
# Collecting azureml-train-restclients-hyperdrive~=1.5.0
#   Downloading azureml_train_restclients_hyperdrive-1.5.0-py3-none-any.whl (18 kB)
# Collecting flake8<=3.7.9,>=3.1.0; python_version >= "3.6"
#   Downloading flake8-3.7.9-py2.py3-none-any.whl (69 kB)
# Requirement already satisfied: six>=1.6 in /azureml-envs/azureml_5d419b151e9c1ce888d07b7a6d7737fd/lib/python3.6/site-packages (from azure-identity<1.3.0,>=1.2.0->azureml-dataprep[fuse]<1.6.0a,>=1.4.10a->azureml-sdk->-r /azureml-environment-setup/condaenv.ru3wm5lg.requirements.txt (line 1)) (1.14.0)
# Collecting azure-core<2.0.0,>=1.0.0
#   Downloading azure_core-1.5.0-py2.py3-none-any.whl (118 kB)
# Collecting msal<2.0.0,>=1.0.0
#   Downloading msal-1.3.0-py2.py3-none-any.whl (48 kB)
# Collecting msal-extensions~=0.1.3
#   Downloading msal_extensions-0.1.3-py2.py3-none-any.whl (9.0 kB)
# Collecting distro>=1.2.0
#   Downloading distro-1.5.0-py2.py3-none-any.whl (18 kB)
# Collecting jeepney>=0.4.2
#   Downloading jeepney-0.4.3-py3-none-any.whl (21 kB)
# Collecting pyasn1>=0.1.1
#   Downloading pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
# Collecting websocket-client>=0.32.0
#   Downloading websocket_client-0.57.0-py2.py3-none-any.whl (200 kB)
# Collecting importlib-metadata
#   Downloading importlib_metadata-1.6.0-py2.py3-none-any.whl (30 kB)
# Collecting ruamel.yaml.clib>=0.1.2; platform_python_implementation == "CPython" and python_version < "3.9"
#   Downloading ruamel.yaml.clib-0.2.0-cp36-cp36m-manylinux1_x86_64.whl (548 kB)
# Collecting backports.weakref
#   Downloading backports.weakref-1.0.post1-py2.py3-none-any.whl (5.2 kB)
# Collecting idna<3,>=2.5
#   Downloading idna-2.9-py2.py3-none-any.whl (58 kB)
# Requirement already satisfied: certifi>=2017.4.17 in /azureml-envs/azureml_5d419b151e9c1ce888d07b7a6d7737fd/lib/python3.6/site-packages (from requests>=2.19.1->azureml-core~=1.5.0->azureml-sdk->-r /azureml-environment-setup/condaenv.ru3wm5lg.requirements.txt (line 1)) (2020.4.5.1)
# Collecting chardet<4,>=3.0.2
#   Downloading chardet-3.0.4-py2.py3-none-any.whl (133 kB)
# Collecting requests-oauthlib>=0.5.0
#   Downloading requests_oauthlib-1.3.0-py2.py3-none-any.whl (23 kB)
# Collecting isodate>=0.6.0
#   Downloading isodate-0.6.0-py2.py3-none-any.whl (45 kB)
# Collecting cffi!=1.11.3,>=1.8
#   Downloading cffi-1.14.0-cp36-cp36m-manylinux1_x86_64.whl (399 kB)
# Collecting mccabe<0.7.0,>=0.6.0
#   Downloading mccabe-0.6.1-py2.py3-none-any.whl (8.6 kB)
# Collecting pycodestyle<2.6.0,>=2.5.0
#   Downloading pycodestyle-2.5.0-py2.py3-none-any.whl (51 kB)
# Collecting pyflakes<2.2.0,>=2.1.0
#   Downloading pyflakes-2.1.1-py2.py3-none-any.whl (59 kB)
# Requirement already satisfied: entrypoints<0.4.0,>=0.3.0 in /azureml-envs/azureml_5d419b151e9c1ce888d07b7a6d7737fd/lib/python3.6/site-packages (from flake8<=3.7.9,>=3.1.0; python_version >= "3.6"->azureml-train-core~=1.5.0->azureml-train~=1.5.0->azureml-sdk->-r /azureml-environment-setup/condaenv.ru3wm5lg.requirements.txt (line 1)) (0.3)
# Collecting portalocker~=1.0
#   Downloading portalocker-1.7.0-py2.py3-none-any.whl (14 kB)
# Collecting zipp>=0.5
#   Downloading zipp-3.1.0-py3-none-any.whl (4.9 kB)
# Collecting oauthlib>=3.0.0
#   Downloading oauthlib-3.1.0-py2.py3-none-any.whl (147 kB)
# Collecting pycparser
#   Downloading pycparser-2.20-py2.py3-none-any.whl (112 kB)
# Building wheels for collected packages: fusepy
#   Building wheel for fusepy (setup.py): started
#   Building wheel for fusepy (setup.py): finished with status 'done'
#   Created wheel for fusepy: filename=fusepy-3.0.1-py3-none-any.whl size=10503 sha256=8a49876d0591873cbe1b911edc3e53133aafa767a16012227487ad4a02b2ef40
#   Stored in directory: /root/.cache/pip/wheels/21/5c/83/1dd7e8a232d12227e5410120f4374b33adeb4037473105b079
# Successfully built fusepy
# Installing collected packages: azureml-dataprep-native, urllib3, idna, chardet, requests, azure-core, pycparser, cffi, cryptography, PyJWT, msal, portalocker, msal-extensions, azure-identity, cloudpickle, distro, dotnetcore2, fusepy, azureml-dataprep, azureml-automl-core, jeepney, SecretStorage, oauthlib, requests-oauthlib, isodate, msrest, adal, msrestazure, azure-common, azure-mgmt-keyvault, pyopenssl, pyasn1, ndg-httpsclient, contextlib2, websocket-client, docker, azure-mgmt-containerregistry, zipp, importlib-metadata, jsonpickle, ruamel.yaml.clib, ruamel.yaml, azure-mgmt-resource, backports.weakref, backports.tempfile, azure-graphrbac, jmespath, azure-mgmt-authorization, azure-mgmt-storage, azure-mgmt-network, pathspec, azureml-core, applicationinsights, azureml-telemetry, azureml-train-automl-client, azureml-pipeline-core, azureml-train-restclients-hyperdrive, mccabe, pycodestyle, pyflakes, flake8, azureml-train-core, azureml-pipeline-steps, azureml-pipeline, azureml-train, azureml-sdk, pyarrow
#
# Successfully installed PyJWT-1.7.1 SecretStorage-3.1.2 adal-1.2.3 applicationinsights-0.11.9 azure-common-1.1.25 azure-core-1.5.0 azure-graphrbac-0.61.1 azure-identity-1.2.0 azure-mgmt-authorization-0.60.0 azure-mgmt-containerregistry-2.8.0 azure-mgmt-keyvault-2.2.0 azure-mgmt-network-10.2.0 azure-mgmt-resource-9.0.0 azure-mgmt-storage-10.0.0 azureml-automl-core-1.5.0.post2 azureml-core-1.5.0.post4 azureml-dataprep-1.5.0 azureml-dataprep-native-14.1.0 azureml-pipeline-1.5.0 azureml-pipeline-core-1.5.0 azureml-pipeline-steps-1.5.0 azureml-sdk-1.5.0 azureml-telemetry-1.5.0 azureml-train-1.5.0 azureml-train-automl-client-1.5.0.post1 azureml-train-core-1.5.0 azureml-train-restclients-hyperdrive-1.5.0 backports.tempfile-1.0 backports.weakref-1.0.post1 cffi-1.14.0 chardet-3.0.4 cloudpickle-1.4.1 contextlib2-0.6.0.post1 cryptography-2.9.2 distro-1.5.0 docker-4.2.0 dotnetcore2-2.1.14 flake8-3.7.9 fusepy-3.0.1 idna-2.9 importlib-metadata-1.6.0 isodate-0.6.0 jeepney-0.4.3 jmespath-0.10.0 jsonpickle-1.4.1 mccabe-0.6.1 msal-1.3.0 msal-extensions-0.1.3 msrest-0.6.13 msrestazure-0.6.3 ndg-httpsclient-0.5.1 oauthlib-3.1.0 pathspec-0.8.0 portalocker-1.7.0 pyarrow-0.17.0 pyasn1-0.4.8 pycodestyle-2.5.0 pycparser-2.20 pyflakes-2.1.1 pyopenssl-19.1.0 requests-2.23.0 requests-oauthlib-1.3.0 ruamel.yaml-0.16.10 ruamel.yaml.clib-0.2.0 urllib3-1.25.9 websocket-client-0.57.0 zipp-3.1.0
#
# #
# # To activate this environment, use:
# # > source activate /azureml-envs/azureml_5d419b151e9c1ce888d07b7a6d7737fd
# #
# # To deactivate an active environment, use:
# # > source deactivate
# #
#
#
# Removing intermediate container b643dab21a4c
#  ---> c27943bf6467
# Step 9/15 : ENV PATH /azureml-envs/azureml_5d419b151e9c1ce888d07b7a6d7737fd/bin:$PATH
#  ---> Running in f598cb673a67
# Removing intermediate container f598cb673a67
#  ---> d127f180be54
# Step 10/15 : ENV AZUREML_CONDA_ENVIRONMENT_PATH /azureml-envs/azureml_5d419b151e9c1ce888d07b7a6d7737fd
#  ---> Running in eb2719d66d96
# Removing intermediate container eb2719d66d96
#  ---> 96e6ce1b8eaa
# Step 11/15 : ENV LD_LIBRARY_PATH /azureml-envs/azureml_5d419b151e9c1ce888d07b7a6d7737fd/lib:$LD_LIBRARY_PATH
#  ---> Running in d42d279ba909
# Removing intermediate container d42d279ba909
#  ---> 1a61152e346f
# Step 12/15 : COPY azureml-environment-setup/spark_cache.py azureml-environment-setup/log4j.properties /azureml-environment-setup/
#  ---> 242059054d07
# Step 13/15 : RUN if [ $SPARK_HOME ]; then /bin/bash -c '$SPARK_HOME/bin/spark-submit "--repositories" "[]" /azureml-environment-setup/spark_cache.py'; fi
#  ---> Running in 06f60d970334
# Removing intermediate container 06f60d970334
#  ---> e83d11510806
# Step 14/15 : ENV AZUREML_ENVIRONMENT_IMAGE True
#  ---> Running in 7505c9644066
# Removing intermediate container 7505c9644066
#  ---> e38f1e2cf345
# Step 15/15 : CMD ["bash"]
#  ---> Running in 3fe1049b9d58
# Removing intermediate container 3fe1049b9d58
#  ---> c34e6749fbcd
# Successfully built c34e6749fbcd
# Successfully tagged azuremldemo9d15d93e.azurecr.io/azureml/azureml_07d0c2f5c176c875537bf8e861a4704c:latest
# 2020/05/18 13:25:12 Successfully executed container: acb_step_0
# 2020/05/18 13:25:12 Executing step ID: acb_step_1. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2020/05/18 13:25:12 Pushing image: azuremldemo9d15d93e.azurecr.io/azureml/azureml_07d0c2f5c176c875537bf8e861a4704c:latest, attempt 1
# The push refers to repository [azuremldemo9d15d93e.azurecr.io/azureml/azureml_07d0c2f5c176c875537bf8e861a4704c]
# 02cc3ff0c3ec: Preparing
# 2aa04749c104: Preparing
# 0f6fcf971d19: Preparing
# c90fac261f05: Preparing
# 62bff4fae5c8: Preparing
# d171615f99b6: Preparing
# e1171d4d60ca: Preparing
# 6ef1a8ae63b7: Preparing
# 85389f9ead9e: Preparing
# f2608f66a0e3: Preparing
# 0e259b09e5f4: Preparing
# 340dc32eb998: Preparing
# df18b66efaa6: Preparing
# ccdb13a20bf2: Preparing
# 9513cdf4e497: Preparing
# 7f083f9454c0: Preparing
# 29f36b5893dc: Preparing
# f2608f66a0e3: Waiting
# 0e259b09e5f4: Waiting
# 340dc32eb998: Waiting
# df18b66efaa6: Waiting
# ccdb13a20bf2: Waiting
# 9513cdf4e497: Waiting
# 7f083f9454c0: Waiting
# 29f36b5893dc: Waiting
# e1171d4d60ca: Waiting
# 6ef1a8ae63b7: Waiting
# 85389f9ead9e: Waiting
# d171615f99b6: Waiting
# c90fac261f05: Pushed
# 62bff4fae5c8: Pushed
# 02cc3ff0c3ec: Pushed
# 0f6fcf971d19: Pushed
# d171615f99b6: Pushed
# e1171d4d60ca: Pushed
# 6ef1a8ae63b7: Pushed
# 340dc32eb998: Pushed
# 0e259b09e5f4: Pushed
# ccdb13a20bf2: Pushed
# 9513cdf4e497: Pushed
# 7f083f9454c0: Pushed
# 85389f9ead9e: Pushed
# f2608f66a0e3: Pushed
# df18b66efaa6: Pushed
# 29f36b5893dc: Pushed
# 2aa04749c104: Pushed
# latest: digest: sha256:cce54a4d0cf66f96642d2fd2b01f8931ece2f866814916cc9d7fc10069928b05 size: 3883
# 2020/05/18 13:28:08 Successfully pushed image: azuremldemo9d15d93e.azurecr.io/azureml/azureml_07d0c2f5c176c875537bf8e861a4704c:latest
# 2020/05/18 13:28:08 Step ID: acb_step_0 marked as successful (elapsed time in seconds: 345.331156)
# 2020/05/18 13:28:08 Populating digests for step ID: acb_step_0...
# 2020/05/18 13:28:10 Successfully populated digests for step ID: acb_step_0
# 2020/05/18 13:28:10 Step ID: acb_step_1 marked as successful (elapsed time in seconds: 175.865061)
# 2020/05/18 13:28:10 The following dependencies were found:
# 2020/05/18 13:28:10
# - image:
#     registry: azuremldemo9d15d93e.azurecr.io
#     repository: azureml/azureml_07d0c2f5c176c875537bf8e861a4704c
#     tag: latest
#     digest: sha256:cce54a4d0cf66f96642d2fd2b01f8931ece2f866814916cc9d7fc10069928b05
#   runtime-dependency:
#     registry: mcr.microsoft.com
#     repository: azureml/base
#     tag: intelmpi2018.3-ubuntu16.04
#     digest: sha256:a1b514f3ba884b9a7695cbba5638933ddaf222e8ce3e8c81e8cdf861679abb05
#   git: {}
#
# Run ID: ch2 was successful after 8m47s
#
# Streaming azureml-logs/55_azureml-execution-tvmps_1c2d0b78db49adcbb04d0c4fe377f88da2b1c48469ea1c6d13a6b660e985ca8e_d.txt
# ========================================================================================================================
# 2020-05-18T13:30:37Z Starting output-watcher...
# 2020-05-18T13:30:37Z IsDedicatedCompute == True, won't poll for Low Pri Preemption
# 4aa9a30f50daf0ec23a7999de3939873de404bdb582af0b5827603aaa7a4f899
#
# Streaming azureml-logs/65_job_prep-tvmps_1c2d0b78db49adcbb04d0c4fe377f88da2b1c48469ea1c6d13a6b660e985ca8e_d.txt
# ===============================================================================================================
# Entering job preparation. Current time:2020-05-18T13:32:13.367628
# Starting job preparation. Current time:2020-05-18T13:32:14.303521
# Extracting the control code.
# fetching and extracting the control code on master node.
# Retrieving project from snapshot: 49bf17a8-1415-4894-b8b0-fab80194249b
# Starting the daemon thread to refresh tokens in background for process with pid = 50
#
# Streaming azureml-logs/70_driver_log.txt
# ========================================
# 2020/05/18 13:32:37 Instrumentation Key Is Empty Skipping App Insight Logger
# Entering context manager injector. Current time:2020-05-18T13:32:39.192661
# Starting the daemon thread to refresh tokens in background for process with pid = 108
# Entering Run History Context Manager.
# Preparing to call script [ train_diabetes.py ] with arguments: ['--output_folder', '/mnt/batch/tasks/shared/LS_root/jobs/azure-ml-demo/azureml/0f877866-e0fe-452f-b14b-610cdf8609cf/mounts/aml_data/azureml/0f877866-e0fe-452f-b14b-610cdf8609cf/model_folder']
# After variable expansion, calling script [ train_diabetes.py ] with arguments: ['--output_folder', '/mnt/batch/tasks/shared/LS_root/jobs/azure-ml-demo/azureml/0f877866-e0fe-452f-b14b-610cdf8609cf/mounts/aml_data/azureml/0f877866-e0fe-452f-b14b-610cdf8609cf/model_folder']
#
# Loading Data...
# Training a decision tree model
# Accuracy: 0.8993333333333333
# AUC: 0.8849105159170803
# Starting the daemon thread to refresh tokens in background for process with pid = 108
#
#
# The experiment completed successfully. Finalizing run...
#
# Streaming azureml-logs/75_job_post-tvmps_1c2d0b78db49adcbb04d0c4fe377f88da2b1c48469ea1c6d13a6b660e985ca8e_d.txt
# ===============================================================================================================
# Entering job release. Current time:2020-05-18T13:33:17.669368
# Starting job release. Current time:2020-05-18T13:33:19.306758
# Logging experiment finalizing status in history service.
# Starting the daemon thread to refresh tokens in background for process with pid = 332
# Entering context manager injector. Current time:2020-05-18T13:33:19.326391
# Job release is complete. Current time:2020-05-18T13:33:20.560695
#
# StepRun(Train Model) Execution Summary
# =======================================
# StepRun( Train Model ) Status: Finished
# {'runId': '0f877866-e0fe-452f-b14b-610cdf8609cf', 'target': 'aml-cluster', 'status': 'Completed', 'startTimeUtc': '2020-05-18T13:30:33.096059Z', 'endTimeUtc': '2020-05-18T13:33:26.559762Z', 'properties': {'azureml.runsource': 'azureml.StepRun', 'ContentSnapshotId': '49bf17a8-1415-4894-b8b0-fab80194249b', 'StepType': 'PythonScriptStep', 'ComputeTargetType': 'AmlCompute', 'azureml.moduleid': 'c2b9c321-c097-4c62-ac82-70f50bc9f038', 'azureml.pipelinerunid': '65df44a8-7d53-418a-aba7-7dd5c754150f', '_azureml.ComputeTargetType': 'amlcompute', 'AzureML.DerivedImageName': 'azureml/azureml_07d0c2f5c176c875537bf8e861a4704c', 'ProcessInfoFile': 'azureml-logs/process_info.json', 'ProcessStatusFile': 'azureml-logs/process_status.json'}, 'inputDatasets': [{'dataset': {'id': 'aefbf644-0faf-4d5c-b230-ca932218b702'}, 'consumptionDetails': {'type': 'RunInput', 'inputName': 'diabetes_train', 'mechanism': 'Direct'}}], 'runDefinition': {'script': 'train_diabetes.py', 'useAbsolutePath': False, 'arguments': ['--output_folder', '$AZUREML_DATAREFERENCE_model_folder'], 'sourceDirectoryDataStore': None, 'framework': 'Python', 'communicator': 'None', 'target': 'aml-cluster', 'dataReferences': {'model_folder': {'dataStoreName': 'aml_data', 'mode': 'Mount', 'pathOnDataStore': 'azureml/0f877866-e0fe-452f-b14b-610cdf8609cf/model_folder', 'pathOnCompute': None, 'overwrite': False}}, 'data': {'diabetes_train': {'dataLocation': {'dataset': {'id': 'aefbf644-0faf-4d5c-b230-ca932218b702'}, 'dataPath': None}, 'createOutputDirectories': False, 'mechanism': 'Direct', 'environmentVariableName': 'diabetes_train', 'pathOnCompute': None, 'overwrite': False}}, 'jobName': None, 'maxRunDurationSeconds': None, 'nodeCount': 1, 'environment': {'name': 'Experiment diabetes-training-pipeline Environment', 'version': 'Autosave_2020-05-18T13:19:09Z_788bcab5', 'python': {'interpreterPath': 'python', 'userManagedDependencies': False, 'condaDependencies': {'channels': ['anaconda', 'conda-forge'], 'dependencies': ['python=3.6.2', {'pip': ['azureml-sdk', 'pyarrow']}, 'scikit-learn', 'ipykernel', 'matplotlib', 'pandas'], 'name': 'azureml_5d419b151e9c1ce888d07b7a6d7737fd'}, 'baseCondaEnvironment': None}, 'environmentVariables': {'EXAMPLE_ENV_VAR': 'EXAMPLE_VALUE'}, 'docker': {'baseImage': 'mcr.microsoft.com/azureml/base:intelmpi2018.3-ubuntu16.04', 'baseDockerfile': None, 'baseImageRegistry': {'address': None, 'username': None, 'password': None}, 'enabled': True, 'shmSize': '1g'}, 'spark': {'repositories': ['[]'], 'packages': [], 'precachePackages': True}, 'inferencingStackVersion': None}, 'history': {'outputCollection': True, 'directoriesToWatch': ['logs']}, 'spark': {'configuration': {'spark.app.name': 'Azure ML Experiment', 'spark.yarn.maxAppAttempts': '1'}}, 'parallelTask': {'maxRetriesPerWorker': 0, 'workerCountPerNode': 1, 'terminalExitCodes': None, 'configuration': {}}, 'amlCompute': {'name': None, 'vmSize': None, 'retainCluster': False, 'clusterMaxNodeCount': 1}, 'tensorflow': {'workerCount': 1, 'parameterServerCount': 1}, 'mpi': {'processCountPerNode': 1}, 'hdi': {'yarnDeployMode': 'Cluster'}, 'containerInstance': {'region': None, 'cpuCores': 2, 'memoryGb': 3.5}, 'exposedPorts': None, 'docker': {'useDocker': True, 'sharedVolumes': True, 'shmSize': '1g', 'arguments': []}, 'cmk8sCompute': {'configuration': {}}, 'itpCompute': {'configuration': {}}}, 'logFiles': {'azureml-logs/20_image_build_log.txt': 'https://azuremldemo1062717072.blob.core.windows.net/azureml/ExperimentRun/dcid.0f877866-e0fe-452f-b14b-610cdf8609cf/azureml-logs/20_image_build_log.txt?sv=2019-02-02&sr=b&sig=ibbf9WZJQch1bQ3hyw%2B6zZzr1wRP6sfaadU%2FUStRrbU%3D&st=2020-05-18T13%3A23%3A33Z&se=2020-05-18T21%3A33%3A33Z&sp=r', 'azureml-logs/55_azureml-execution-tvmps_1c2d0b78db49adcbb04d0c4fe377f88da2b1c48469ea1c6d13a6b660e985ca8e_d.txt': 'https://azuremldemo1062717072.blob.core.windows.net/azureml/ExperimentRun/dcid.0f877866-e0fe-452f-b14b-610cdf8609cf/azureml-logs/55_azureml-execution-tvmps_1c2d0b78db49adcbb04d0c4fe377f88d ...
#
#
#
#
# StepRunId: 2fe8d0a8-5b64-4da9-993b-6a3643e12006
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/diabetes-training-pipeline/runs/2fe8d0a8-5b64-4da9-993b-6a3643e12006?wsid=/subscriptions/2a43b2d1-03c5-46d9-aa44-98475cf19902/resourcegroups/azure-ml-demo/workspaces/azure-ml-demo
# StepRun( Register Model ) Status: NotStarted
# StepRun( Register Model ) Status: Running
#
# Streaming azureml-logs/55_azureml-execution-tvmps_1c2d0b78db49adcbb04d0c4fe377f88da2b1c48469ea1c6d13a6b660e985ca8e_d.txt
# ========================================================================================================================
# 2020-05-18T13:34:56Z Starting output-watcher...
# 2020-05-18T13:34:56Z IsDedicatedCompute == True, won't poll for Low Pri Preemption
# 0c69c1f3ce49a28c2fc8bcb96e8fbb01aa4605ac04c210501ea225a35b90252b
#
# Streaming azureml-logs/65_job_prep-tvmps_1c2d0b78db49adcbb04d0c4fe377f88da2b1c48469ea1c6d13a6b660e985ca8e_d.txt
# ===============================================================================================================
# Entering job preparation. Current time:2020-05-18T13:34:57.853048
# Starting job preparation. Current time:2020-05-18T13:34:58.565510
# Extracting the control code.
# fetching and extracting the control code on master node.
# Retrieving project from snapshot: 49bf17a8-1415-4894-b8b0-fab80194249b
# Starting the daemon thread to refresh tokens in background for process with pid = 49
# Starting project file download.
# Finished project file download.
# downloadDataStore - Download from datastores if requested.
# Entering context manager injector. Current time:2020-05-18T13:35:00.163825
#
# Streaming azureml-logs/70_driver_log.txt
# ========================================
# 2020/05/18 13:35:02 Instrumentation Key Is Empty Skipping App Insight Logger
# Entering context manager injector. Current time:2020-05-18T13:35:04.266212
# Starting the daemon thread to refresh tokens in background for process with pid = 107
# Entering Run History Context Manager.
# Preparing to call script [ register_diabetes.py ] with arguments: ['--model_folder', '/mnt/batch/tasks/shared/LS_root/jobs/azure-ml-demo/azureml/2fe8d0a8-5b64-4da9-993b-6a3643e12006/mounts/aml_data/azureml/0f877866-e0fe-452f-b14b-610cdf8609cf/model_folder']
# After variable expansion, calling script [ register_diabetes.py ] with arguments: ['--model_folder', '/mnt/batch/tasks/shared/LS_root/jobs/azure-ml-demo/azureml/2fe8d0a8-5b64-4da9-993b-6a3643e12006/mounts/aml_data/azureml/0f877866-e0fe-452f-b14b-610cdf8609cf/model_folder']
#
# Loading model from /mnt/batch/tasks/shared/LS_root/jobs/azure-ml-demo/azureml/2fe8d0a8-5b64-4da9-993b-6a3643e12006/mounts/aml_data/azureml/0f877866-e0fe-452f-b14b-610cdf8609cf/model_folder
#
# Streaming azureml-logs/75_job_post-tvmps_1c2d0b78db49adcbb04d0c4fe377f88da2b1c48469ea1c6d13a6b660e985ca8e_d.txt
# ===============================================================================================================
# Entering job release. Current time:2020-05-18T13:35:12.403370
# Starting job release. Current time:2020-05-18T13:35:13.988341
# Logging experiment finalizing status in history service.
# Starting the daemon thread to refresh tokens in background for process with pid = 143
# Entering context manager injector. Current time:2020-05-18T13:35:14.007803
# Job release is complete. Current time:2020-05-18T13:35:15.723302
#
# StepRun(Register Model) Execution Summary
# ==========================================
# StepRun( Register Model ) Status: Finished
# {'runId': '2fe8d0a8-5b64-4da9-993b-6a3643e12006', 'target': 'aml-cluster', 'status': 'Completed', 'startTimeUtc': '2020-05-18T13:34:02.707277Z', 'endTimeUtc': '2020-05-18T13:35:17.662243Z', 'properties': {'azureml.runsource': 'azureml.StepRun', 'ContentSnapshotId': '49bf17a8-1415-4894-b8b0-fab80194249b', 'StepType': 'PythonScriptStep', 'ComputeTargetType': 'AmlCompute', 'azureml.moduleid': 'c385c4a7-4ea6-442e-b15e-aec4a3b9b0e7', 'azureml.pipelinerunid': '65df44a8-7d53-418a-aba7-7dd5c754150f', '_azureml.ComputeTargetType': 'amlcompute', 'AzureML.DerivedImageName': 'azureml/azureml_07d0c2f5c176c875537bf8e861a4704c', 'ProcessInfoFile': 'azureml-logs/process_info.json', 'ProcessStatusFile': 'azureml-logs/process_status.json'}, 'inputDatasets': [], 'runDefinition': {'script': 'register_diabetes.py', 'useAbsolutePath': False, 'arguments': ['--model_folder', '$AZUREML_DATAREFERENCE_model_folder'], 'sourceDirectoryDataStore': None, 'framework': 'Python', 'communicator': 'None', 'target': 'aml-cluster', 'dataReferences': {'model_folder': {'dataStoreName': 'aml_data', 'mode': 'Mount', 'pathOnDataStore': 'azureml/0f877866-e0fe-452f-b14b-610cdf8609cf/model_folder', 'pathOnCompute': None, 'overwrite': False}}, 'data': {}, 'jobName': None, 'maxRunDurationSeconds': None, 'nodeCount': 1, 'environment': {'name': 'Experiment diabetes-training-pipeline Environment', 'version': 'Autosave_2020-05-18T13:19:09Z_788bcab5', 'python': {'interpreterPath': 'python', 'userManagedDependencies': False, 'condaDependencies': {'channels': ['anaconda', 'conda-forge'], 'dependencies': ['python=3.6.2', {'pip': ['azureml-sdk', 'pyarrow']}, 'scikit-learn', 'ipykernel', 'matplotlib', 'pandas'], 'name': 'azureml_5d419b151e9c1ce888d07b7a6d7737fd'}, 'baseCondaEnvironment': None}, 'environmentVariables': {'EXAMPLE_ENV_VAR': 'EXAMPLE_VALUE'}, 'docker': {'baseImage': 'mcr.microsoft.com/azureml/base:intelmpi2018.3-ubuntu16.04', 'baseDockerfile': None, 'baseImageRegistry': {'address': None, 'username': None, 'password': None}, 'enabled': True, 'shmSize': '1g'}, 'spark': {'repositories': ['[]'], 'packages': [], 'precachePackages': True}, 'inferencingStackVersion': None}, 'history': {'outputCollection': True, 'directoriesToWatch': ['logs']}, 'spark': {'configuration': {'spark.app.name': 'Azure ML Experiment', 'spark.yarn.maxAppAttempts': '1'}}, 'parallelTask': {'maxRetriesPerWorker': 0, 'workerCountPerNode': 1, 'terminalExitCodes': None, 'configuration': {}}, 'amlCompute': {'name': None, 'vmSize': None, 'retainCluster': False, 'clusterMaxNodeCount': 1}, 'tensorflow': {'workerCount': 1, 'parameterServerCount': 1}, 'mpi': {'processCountPerNode': 1}, 'hdi': {'yarnDeployMode': 'Cluster'}, 'containerInstance': {'region': None, 'cpuCores': 2, 'memoryGb': 3.5}, 'exposedPorts': None, 'docker': {'useDocker': True, 'sharedVolumes': True, 'shmSize': '1g', 'arguments': []}, 'cmk8sCompute': {'configuration': {}}, 'itpCompute': {'configuration': {}}}, 'logFiles': {'azureml-logs/55_azureml-execution-tvmps_1c2d0b78db49adcbb04d0c4fe377f88da2b1c48469ea1c6d13a6b660e985ca8e_d.txt': 'https://azuremldemo1062717072.blob.core.windows.net/azureml/ExperimentRun/dcid.2fe8d0a8-5b64-4da9-993b-6a3643e12006/azureml-logs/55_azureml-execution-tvmps_1c2d0b78db49adcbb04d0c4fe377f88da2b1c48469ea1c6d13a6b660e985ca8e_d.txt?sv=2019-02-02&sr=b&sig=3FaeEnBlUZeG%2BmFuTKfo2WN0dKdONPxEko%2FQOq0LEVI%3D&st=2020-05-18T13%3A25%3A24Z&se=2020-05-18T21%3A35%3A24Z&sp=r', 'azureml-logs/65_job_prep-tvmps_1c2d0b78db49adcbb04d0c4fe377f88da2b1c48469ea1c6d13a6b660e985ca8e_d.txt': 'https://azuremldemo1062717072.blob.core.windows.net/azureml/ExperimentRun/dcid.2fe8d0a8-5b64-4da9-993b-6a3643e12006/azureml-logs/65_job_prep-tvmps_1c2d0b78db49adcbb04d0c4fe377f88da2b1c48469ea1c6d13a6b660e985ca8e_d.txt?sv=2019-02-02&sr=b&sig=hUwwWahuHeZACNOLbMQfFyuPCheG%2F1Jgub%2BlPLojKSA%3D&st=2020-05-18T13%3A25%3A24Z&se=2020-05-18T21%3A35%3A24Z&sp=r', 'azureml-logs/70_driver_log.txt': 'https://azuremldemo1062717072.blob.core.windows.net/azureml/Experiment ...
#
#
#
# PipelineRun Execution Summary
# ==============================
# PipelineRun Status: Finished
# {'runId': '65df44a8-7d53-418a-aba7-7dd5c754150f', 'status': 'Completed', 'startTimeUtc': '2020-05-18T13:19:01.418455Z', 'endTimeUtc': '2020-05-18T13:35:23.857456Z', 'properties': {'azureml.runsource': 'azureml.PipelineRun', 'runSource': 'SDK', 'runType': 'SDK', 'azureml.parameters': '{}'}, 'inputDatasets': [], 'logFiles': {'logs/azureml/executionlogs.txt': 'https://azuremldemo1062717072.blob.core.windows.net/azureml/ExperimentRun/dcid.65df44a8-7d53-418a-aba7-7dd5c754150f/logs/azureml/executionlogs.txt?sv=2019-02-02&sr=b&sig=qM3RaoDO9TRjxJmypi1WQA8vCBBvnu5MpZoXvOOZx7s%3D&st=2020-05-18T13%3A25%3A26Z&se=2020-05-18T21%3A35%3A26Z&sp=r', 'logs/azureml/stderrlogs.txt': 'https://azuremldemo1062717072.blob.core.windows.net/azureml/ExperimentRun/dcid.65df44a8-7d53-418a-aba7-7dd5c754150f/logs/azureml/stderrlogs.txt?sv=2019-02-02&sr=b&sig=qvs%2BoUrW4FXV1WD4%2F%2Bam4h%2FfuHWFUc%2F156%2BVz%2B04hjA%3D&st=2020-05-18T13%3A25%3A26Z&se=2020-05-18T21%3A35%3A26Z&sp=r', 'logs/azureml/stdoutlogs.txt': 'https://azuremldemo1062717072.blob.core.windows.net/azureml/ExperimentRun/dcid.65df44a8-7d53-418a-aba7-7dd5c754150f/logs/azureml/stdoutlogs.txt?sv=2019-02-02&sr=b&sig=UgtvY8U5%2BE4W%2FDmsZeUsFq0i3fzAokWKP%2Bop4EYEDNI%3D&st=2020-05-18T13%3A25%3A26Z&se=2020-05-18T21%3A35%3A26Z&sp=r'}}
# 'Finished'

# %% [markdown]
# The widget above shows details of the pipeline as it runs. You can also monitor pipeline runs in the **Experiments** page in [Azure Machine Learning studio](https://ml.azure.com).
#
# When the pipeline has finished, a new model should be registered with a *Training context* tag indicating it was trained in a pipeline. Run the following code to verify this.

# %%
from azureml.core import Model

for model in Model.list(ws):
    print(model.name, 'version:', model.version)
    for tag_name in model.tags:
        tag = model.tags[tag_name]
        print ('\t',tag_name, ':', tag)
    for prop_name in model.properties:
        prop = model.properties[prop_name]
        print ('\t',prop_name, ':', prop)
    print('\n')
# Out:
# diabetes_model version: 11
# 	 Training context : Pipeline
#
#
# diabetes_model version: 10
# 	 Training context : Estimator + Environment (Decision Tree)
# 	 AUC : 0.8850872543910331
# 	 Accuracy : 0.9
#
#
# diabetes_model version: 9
# 	 Training context : SKLearn Estimator (tabular dataset)
# 	 AUC : 0.8568632924585982
# 	 Accuracy : 0.7893333333333333
#
#
# diabetes_model version: 8
# 	 Training context : Parameterized SKLearn Estimator
# 	 AUC : 0.8483904671874223
# 	 Accuracy : 0.7736666666666666
#
#
# diabetes_model version: 7
# 	 Training context : Estimator
# 	 AUC : 0.8484929598487486
# 	 Accuracy : 0.774
#
#
# diabetes_model version: 6
# 	 Training context : Azure ML compute
# 	 AUC : 0.8847430678259885
# 	 Accuracy : 0.8991111111111111
#
#
# diabetes_model version: 5
# 	 Training context : Estimator + Environment (Decision Tree)
# 	 AUC : 0.8850733188167415
# 	 Accuracy : 0.8993333333333333
#
#
# diabetes_model version: 4
# 	 Training context : SKLearn Estimator (tabular dataset)
# 	 AUC : 0.8568632924585982
# 	 Accuracy : 0.7893333333333333
#
#
# diabetes_model version: 3
# 	 Training context : Using Datastore
# 	 AUC : 0.846851712258014
# 	 Accuracy : 0.7788888888888889
#
#
# diabetes_model version: 2
# 	 Training context : Parameterized SKLearn Estimator
# 	 AUC : 0.8483904671874223
# 	 Accuracy : 0.7736666666666666
#
#
# diabetes_model version: 1
# 	 Training context : Estimator
# 	 AUC : 0.8484929598487486
# 	 Accuracy : 0.774
#
#
# amlstudio-predict-diabetes version: 1
# 	 CreatedByAMLStudio : true

# %% [markdown]
# This is a simple example, designed to demonstrate the principle. In reality, you could build more sophisticated logic into the pipeline steps - for example, evaluating the model against some test data to calculate a performance metric like AUC or accuracy, comparing the metric to that of any previously registered versions of the model, and only registering the new model if it performs better.
#
# You can use the [Azure Machine Learning extension for Azure DevOps](https://marketplace.visualstudio.com/items?itemName=ms-air-aiagility.vss-services-azureml) to combine Azure ML pipelines with Azure DevOps pipelines (yes, it *is* confusing that they have the same name!) and integrate model retraining into a *continuous integration/continuous deployment (CI/CD)* process. For example you could use an Azure DevOps *build* pipeline to trigger an Azure ML pipeline that trains and registers a model, and when the model is registered it could trigger an Azure Devops *release* pipeline that deploys the model as a web service, along with the application or service that consumes the model.
